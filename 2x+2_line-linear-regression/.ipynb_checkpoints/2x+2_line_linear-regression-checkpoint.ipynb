# %%
# %matplotlib inline

#imports
from numpy import *
import matplotlib.pyplot as plt

# %%
points = genfromtxt('2x+2_line-data.csv', delimiter=',')
print(points)
#Extract columns
x = array(points[0:10,0])
y = array(points[:,1])
print(x)
print(y)
# Out:
# [[ 5. 12.]
#  [ 1.  4.]
#  [ 3.  8.]
#  [ 2.  6.]
#  [10. 22.]
#  [ 7. 16.]
#  [ 9. 20.]
#  [ 8. 18.]
#  [ 4. 10.]
#  [ 6. 14.]]
# [ 5.  1.  3.  2. 10.  7.  9.  8.  4.  6.]
# [12.  4.  8.  6. 22. 16. 20. 18. 10. 14.]

# %%
#Plot the dataset
plt.scatter(x,y)
plt.xlabel('X - values')
plt.ylabel('Y - values')
plt.title('Y=f(x)=2x+2=mx+c')
plt.show()

# %%
def compute_cost(b, m, points):
    total_cost = 0
    N = float(len(points))
    
    #Compute sum of squared errors SE = (y - (mx+b))^2 => gives positive values
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        total_cost += (y - (m * x + b)) ** 2
        
    #Return average of squared error
    return total_cost/N # mean of squared error MSE

# %%
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    cost_graph = []

    #For every iteration, optimize b, m and compute its cost
    for i in range(num_iterations):
        cost_graph.append(compute_cost(b, m, points)) # every iteration generates some predictions which are being optimized
        b, m = step_gradient(b, m, array(points), learning_rate)

    return [b, m, cost_graph]

def step_gradient(b_current, m_current, points, learning_rate):
    m_gradient = 0
    b_gradient = 0
    N = float(len(points))

    #Calculate Gradient
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        m_gradient += - (2/N) * x * (y - (m_current * x + b_current))
        b_gradient += - (2/N) * (y - (m_current * x + b_current))
    
    #Update current m and b
    m_updated = m_current - learning_rate * m_gradient
    b_updated = b_current - learning_rate * b_gradient

    #Return updated parameters
    return b_updated, m_updated

# %%
#hyperparamters
#change learning rate to 0.0001 then see the magic
learning_rate = 0.01 #alpha
initial_b = 0 #initial bias term 
initial_m = 0 #initial slope or weight term W
num_iterations = 5

# %%
b, m, cost_graph = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)

#Print optimized parameters
print ('Optimized b:', b)
print ('Optimized m:', m)
print (' Cost Graph:', cost_graph )

#Print error with optimized parameters
print ('Minimized cost:', compute_cost(b, m, points))
# Out:
# Optimized b: 0.3567008636
# Optimized m: 2.2350130286
#  Cost Graph: [202.0, 9.838799999999992, 1.0173832199999997, 0.607900289418, 0.584408777822989]
# Minimized cost: 0.5786665343927326

# %%
plt.plot(cost_graph)
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
plt.title('Cost per iteration')
plt.show()

# %%
#Plot dataset
plt.scatter(x, y)
#Predict y values
pred = m * x + b
#Plot predictions as line of best fit
plt.plot(x, pred, c='r')
plt.xlabel('X-values')
plt.ylabel('Y-values')
plt.title('Line of best fit')
plt.show()
